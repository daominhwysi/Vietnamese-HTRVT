# %%
# prompt: download https://www.kaggle.com/datasets/minhdao727/testset/data

# You need to have the Kaggle API installed and configured.
# You can find instructions on how to do this on the Kaggle website.

# Assuming you have your kaggle.json file in the correct location (e.g., ~/.kaggle/).
# !kaggle datasets download minhdao727/fixedextendvnondb -p /content/data/
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 6.5 MB/s eta 0:00:00
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105786 sha256=21764621d3c0b8b3aa7bab371e2b5dacd61b0debecc3f5ae359861d67db7bedc
#   Stored in directory: /root/.cache/pip/wheels/9f/af/22/bf406f913dc7506a485e60dce8143741abd0a92a19337d83a3
# Successfully built kaggle
# ...
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/output/extendedvnondb/ordered_images/14149.txt
#   inflating: /content/output/extendedvnondb/ordered_images/1415.jpeg
#   inflating: /content/output/extendedvnondb/ordered_images/1415.txt
# ...

# %%
# !pip install -q condacolab
# !pip install ipykernel

# %%
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !git clone https://github.com/daominhwysi/Vietnamese-HTRVT.git
# Out:
# Cloning into 'Vietnamese-HTRVT'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 139 (delta 48), reused 84 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (139/139), 3.72 MiB | 32.87 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# prompt: forcing !mv Vietnamese-HTRVT/* .
# !rm -rf data
# !mv Vietnamese-HTRVT/* .

# %%
# !conda env create -n myenv -f environment.yaml
# !source ~/.bashrc
# !source /usr/local/etc/profile.d/conda.sh
# !conda run -n myenv python --version  # Kiểm tra xem môi trường đã được kích hoạt

# !conda install -n myenv ipykernel
# Out:
# ...
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# python-3.8.0         | 34.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# openssl-1.1.1w       | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# tk-8.6.12            | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pip-24.2             | 2.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# sqlite-3.33.0        | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# setuptools-68.2.2    | 948 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !python -m ipykernel install --user --name=myenv
# Out:
# Installed kernelspec myenv in /root/.local/share/jupyter/kernels/myenv

# %%
# !conda run -n myenv python --version  # Hoặc bất cứ lệnh gì mày muốn chạy
# Out:
# Python 3.8.0

# %%
# prompt: download https://huggingface.co/AnhxtanhHP/HTR-VT-Vietnamese/resolve/main/best_CER.pth?download=true
# !wget https://huggingface.co/AnhxtanhHP/HTR-VT-Vietnamese/resolve/main/best_CER.pth
# Out:
# --2024-10-19 12:38:10--  https://huggingface.co/AnhxtanhHP/HTR-VT-Vietnamese/resolve/main/best_CER.pth
# Resolving huggingface.co (huggingface.co)... 3.165.160.12, 3.165.160.11, 3.165.160.59, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.12|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !mkdir output

# %%
# !ls

# %%
# !mv best_CER.pth output

# %%
# !conda run -n myenv python train.py --exp-name Evnondb \
  --max-lr 1e-4 \
  --train-bs 96 \
  --val-bs 8 \
  --weight-decay 0.5 \
  --mask-ratio 0.4 \
  --attn-mask-ratio 0.1 \
  --max-span-length 8 \
  --img-size 512 64 \
  --proj 8 \
  --dila-ero-max-kernel 2 \
  --dila-ero-iter 1 \
  --proba 0.5 \
  --alpha 1 \
  --total-iter 100000 \
Evnondb
# Out:
# CondaError: KeyboardInterrupt
